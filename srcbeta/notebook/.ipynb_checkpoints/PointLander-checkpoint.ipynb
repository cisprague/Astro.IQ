# %% [markdown]
# # Two Dimensional Point Landing
# The dynamics of the system are:
# $$
# \left \{
# \begin{align}
# \dot{x} &= v_x \\
# \dot{y} &= v_y \\
# \dot{v}_x &= \frac{T u}{m} \hat{u}_x \\
# \dot{v}_y &= \frac{T u}{m} \hat{u}_y - g\\
# \dot{m} &= -\frac{T}{I_{sp}g_0}
# \end{align}
# \right\}
# $$

# %%
from sympy import *

# %%
# State
x, y, vx, vy, m = symbols('x y vx vy m')
r = Matrix([x, y])
v = Matrix([vx, vy])
s = Matrix([r, v, [m]])

# Costate
lx, ly, lvx, lvy, lm = symbols('lx ly lvx lvy lvm')
lr = Matrix([lx, ly])
lv = Matrix([lvx, lvy])
l  = Matrix([lr, lv, [lm]])

# Fullstate
fs = Matrix([s, l])

# Control
u, st, ct = symbols('u st ct')
ut = Matrix([st, ct])
cont = Matrix([[u], ut])

# Parameters
T, Isp, g0, a = symbols('T Isp g0 a')
c = Isp*g0
g = Matrix([0, -g0])

# %%
# Dynamics
dr = v
dv = T*u/m*ut + g
dm = -T/c*u
ds = Matrix([dr, dv, [dm]])

# %%
# Lagrangian Cost
L = 1/c*((1-a)*T**2*u**2 + a*T*u)

# %%
# Hamiltonian
H = l.dot(ds) + L

# %%
# Costate Dynamics
dl = -Matrix([H.diff(i) for i in s])

# %%
# Fullstate dynamics
dfs = Matrix([ds, dl])

# %% [markdown]
# # Implementation

# %%
import sys
sys.path.append('../')
from trajectory.landing import PointLander

# %%
# Instantiate the lander with Hermite-Simpson mass optimal control
Apollo = PointLander(meth='HS', obj='mass', nseg=100)

# %%
# Use European Space Agency's PyGMO
from PyGMO import *

# %%
# Use sequentual least square quadratic programming
algo = algorithm.pso(5)

# %%
pop = population(Apollo, 4)

# %%
pop = algo.evolve(pop)
# Out:
#   NIT    FC           OBJFUN            GNORM
#     1   561     8.021550E+03     1.000017E+00
#     2  1122     8.020550E+03     1.000017E+00
#     3  1683     8.015936E+03     1.000017E+00
#     4  2244     8.009949E+03     1.000017E+00
#     5  2805     7.999373E+03     1.000017E+00
#     6  3366     7.994316E+03     1.000017E+00
#     7  3927     7.985166E+03     1.000017E+00
#     8  4488     7.975530E+03     1.000017E+00
#     9  5049     7.961556E+03     1.000017E+00
#    10  5610     7.934291E+03     1.000017E+00
#    11  6171     7.899334E+03     1.000017E+00
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: 7899.33399291
#             Iterations: 11
#             Function evaluations: 6171
#             Gradient evaluations: 11

# %%
Apollo.PlotTraj(pop.champion.x)
