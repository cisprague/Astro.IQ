# %%
import sys
sys.path.append('../')
from numpy import *
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from ML import MLP
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.py:874: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
# We load the data to be regressed
data = load("../Data/ML/Mars_Far.npy")
# This is what the data looks like:

# %%
'''
Here we instantiate a multi-layer perceptron with 4 hidden layers,
each with __ neurons (features). We also state the input columns
and output columns.
'''

iin    = [0,1,2,3,4]   # Input the state
iout   = [5,6]         # Target the controls
layers = [10,20,15,10] # Hidden layer structure

# Instantiate the artificial neural network
net = MLP().build(data, iin, iout, layers) # TODO: Make nice __repr__

# %%
# Now we train on the data
net.train(1e-2, 5000)
# Out:
# Cost 0: 1.16803
# Cost 50: 1.09802
# Cost 100: 0.998515
# Cost 150: 0.944058
# Cost 200: 0.940172
# Cost 250: 0.933975
# Cost 300: 0.92865
# Cost 350: 0.923031
# Cost 400: 0.915885
# Cost 450: 0.905383
# Cost 500: 0.891833
# Cost 550: 0.890505
# Cost 600: 0.890025
# Cost 650: 0.889622
# Cost 700: 0.889265
# Cost 750: 0.888965
# Cost 800: 0.888713
# Cost 850: 0.888503
# Cost 900: 0.888321
# Cost 950: 0.888158
# Cost 1000: 0.88801
# Cost 1050: 0.887874
# Cost 1100: 0.887747
# Cost 1150: 0.887625
# Cost 1200: 0.887508
# Cost 1250: 0.887393
# Cost 1300: 0.887283
# Cost 1350: 0.887175
# Cost 1400: 0.88706
# Cost 1450: 0.886946
# Cost 1500: 0.886827
# Cost 1550: 0.886705
# Cost 1600: 0.886575
# Cost 1650: 0.886434
# Cost 1700: 0.886297
# Cost 1750: 0.886154
# Cost 1800: 0.886019
# Cost 1850: 0.885887
# Cost 1900: 0.885751
# Cost 1950: 0.885611
# Cost 2000: 0.885475
# Cost 2050: 0.885347
# Cost 2100: 0.885227
# Cost 2150: 0.885107
# Cost 2200: 0.884987
# Cost 2250: 0.884864
# Cost 2300: 0.884738
# Cost 2350: 0.884622
# Cost 2400: 0.884503
# Cost 2450: 0.884382
# Cost 2500: 0.884254
# Cost 2550: 0.884117
# Cost 2600: 0.883961
# Cost 2650: 0.883781
# Cost 2700: 0.883598
# Cost 2750: 0.883436
# Cost 2800: 0.883292
# Cost 2850: 0.883155
# Cost 2900: 0.883015
# Cost 2950: 0.882879
# Cost 3000: 0.882748
# Cost 3050: 0.882619
# Cost 3100: 0.882497
# Cost 3150: 0.882377
# Cost 3200: 0.882263
# Cost 3250: 0.882154
# Cost 3300: 0.882048
# Cost 3350: 0.881945
# Cost 3400: 0.881845
# Cost 3450: 0.881744
# Cost 3500: 0.881645
# Cost 3550: 0.88155
# Cost 3600: 0.881452
# Cost 3650: 0.881352
# Cost 3700: 0.881252
# Cost 3750: 0.881154
# Cost 3800: 0.881053
# Cost 3850: 0.880949
# Cost 3900: 0.880841
# Cost 3950: 0.880731
# Cost 4000: 0.88062
# Cost 4050: 0.880509
# Cost 4100: 0.880399
# Cost 4150: 0.880285
# Cost 4200: 0.880169
# Cost 4250: 0.880053
# Cost 4300: 0.879931
# Cost 4350: 0.879803
# Cost 4400: 0.879672
# Cost 4450: 0.879524
# Cost 4500: 0.879368
# Cost 4550: 0.879197
# Cost 4600: 0.879008
# Cost 4650: 0.87879
# Cost 4700: 0.878552
# Cost 4750: 0.878281
# Cost 4800: 0.87797
# Cost 4850: 0.877621
# Cost 4900: 0.877277
# Cost 4950: 0.876944

# %%
plt.plot(net.costs)
plt.show()

# %%
# Lets look at data
throttle = net.output_data[:,0]
throttlep = net.predictions_us[:,0]

plt.close('all')
plt.subplot(211)
plt.plot(throttle, '.')
plt.title('Data')
plt.subplot(212)
plt.plot(throttlep, '.')
plt.title('Predictions')
plt.show()
